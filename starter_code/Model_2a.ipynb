# %%
import pandas as pd

df = pd.read_csv("exoplanet_data.csv")
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
df.shape
# Out:
# (6991, 41)

# %%
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
df.shape
# Out:
# (6991, 41)

# %%
# Set features. This will also be used as your x values.
# selected_features = df[['names', 'of', 'selected', 'features', 'here']]
X = df[['koi_fpflag_co', 
        'koi_fpflag_nt', 
        'koi_fpflag_ss', 
        'koi_model_snr',
        'koi_prad',
        'koi_fpflag_ec',
        'koi_prad_err2',
        'koi_steff_err2',
        'koi_steff_err1',
        'koi_duration_err1',
        'koi_duration_err2',
        'koi_prad_err1',
        'koi_time0bk_err1',
        'koi_time0bk_err2',
        'koi_duration',
        'koi_period',
        'koi_depth',
        'koi_period_err1',
        'koi_insol_err1',
        'koi_impact',
        'koi_period_err2',
        'koi_insol',
        'koi_teq',
        'koi_insol_err2',
        'koi_depth_err1',
        'koi_time0bk',
        'koi_depth_err2',
        'ra',
        'koi_srad_err1',
        'dec',
        'koi_impact_err1',
        'koi_kepmag',
        'koi_impact_err2',
        'koi_slogg_err2']]
y = df["koi_disposition"]
print(X.shape, y.shape)
# Out:
# (6991, 34) (6991,)

# %%
feature_names = X.columns

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.8707093821510298

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.9061784897025171

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.107606009505025, 'koi_fpflag_co'),
#  (0.09336042425938637, 'koi_fpflag_nt'),
#  (0.0688098263891143, 'koi_fpflag_ss'),
#  (0.05945211575639642, 'koi_model_snr'),
#  (0.05437757028609435, 'koi_prad'),
#  (0.04252005413317542, 'koi_fpflag_ec'),
#  (0.03655735530430535, 'koi_prad_err2'),
#  (0.03409086952371732, 'koi_duration_err2'),
#  (0.03371302427277809, 'koi_prad_err1'),
#  (0.03203831095173648, 'koi_steff_err1'),
#  (0.030867924695254904, 'koi_duration_err1'),
#  (0.026049579154040547, 'koi_steff_err2'),
#  (0.024199488726916848, 'koi_duration'),
#  (0.023423801806069098, 'koi_time0bk_err2'),
#  (0.023277657347252362, 'koi_insol_err1'),
#  (0.02282693795500412, 'koi_time0bk_err1'),
#  (0.02253348246684669, 'koi_period'),
#  (0.021787023728653505, 'koi_depth'),
#  (0.019127276635426644, 'koi_impact'),
#  (0.018492407655790726, 'koi_period_err2'),
#  (0.018134404589617098, 'koi_period_err1'),
#  (0.01642113140745794, 'koi_insol'),
#  (0.016343071249768155, 'koi_insol_err2'),
#  (0.016024954304082913, 'koi_depth_err1'),
#  (0.01586843933520394, 'koi_teq'),
#  (0.015271923794876767, 'koi_time0bk'),
#  (0.015054669054606734, 'koi_depth_err2'),
#  (0.014812515226691218, 'koi_srad_err1'),
#  (0.014055921661890361, 'ra'),
#  (0.01321641282962292, 'dec'),
#  (0.012851122058788135, 'koi_kepmag'),
#  (0.012668931308274628, 'koi_slogg_err2'),
#  (0.012114307219094697, 'koi_impact_err2'),
#  (0.01205105540703986, 'koi_impact_err1')]
