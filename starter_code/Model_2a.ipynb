# %%
import pandas as pd

df = pd.read_csv("exoplanet_data.csv")
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
df.shape
# Out:
# (6991, 41)

# %%
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
df.shape
# Out:
# (6991, 41)

# %%
# Set features. This will also be used as your x values.
# selected_features = df[['names', 'of', 'selected', 'features', 'here']]
X = df[['koi_fpflag_co', 
        'koi_fpflag_nt', 
        'koi_fpflag_ss', 
        'koi_model_snr',
        'koi_prad',
        'koi_fpflag_ec',
        'koi_prad_err2',
        'koi_steff_err2',
        'koi_steff_err1',
        'koi_duration_err1',
        'koi_duration_err2',
        'koi_prad_err1',
        'koi_time0bk_err1',
        'koi_time0bk_err2',
        'koi_duration',
        'koi_period',
        'koi_depth',
        'koi_period_err1',
        'koi_insol_err1',
        'koi_impact',
        'koi_period_err2',
        'koi_insol',
        'koi_teq',
        'koi_insol_err2',
        'koi_depth_err1',
        'koi_time0bk',
        'koi_depth_err2',
        'ra',
        'koi_srad_err1',
        'dec',
        'koi_impact_err1',
        'koi_kepmag',
        'koi_impact_err2',
        'koi_slogg_err2']]
y = df["koi_disposition"]
print(X.shape, y.shape)
# Out:
# (6991, 34) (6991,)

# %%
feature_names = X.columns

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.8483981693363845

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.8993135011441648

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.10740478496046425, 'koi_fpflag_co'),
#  (0.09788915540520718, 'koi_fpflag_nt'),
#  (0.07012490650607373, 'koi_fpflag_ss'),
#  (0.057127565595455204, 'koi_model_snr'),
#  (0.05141732912766579, 'koi_prad'),
#  (0.03820509672376851, 'koi_fpflag_ec'),
#  (0.037422208693124966, 'koi_duration_err1'),
#  (0.035876287096038136, 'koi_prad_err2'),
#  (0.034005088269908265, 'koi_duration_err2'),
#  (0.033545035078294545, 'koi_prad_err1'),
#  (0.03284298301489253, 'koi_steff_err1'),
#  (0.026545537447909252, 'koi_steff_err2'),
#  (0.024989859488024534, 'koi_duration'),
#  (0.02462630921794099, 'koi_depth'),
#  (0.02321618794306598, 'koi_insol_err1'),
#  (0.022964700510463832, 'koi_time0bk_err1'),
#  (0.022809690327970124, 'koi_time0bk_err2'),
#  (0.022717658448403767, 'koi_period'),
#  (0.018820289690763967, 'koi_impact'),
#  (0.018220712905449025, 'koi_period_err1'),
#  (0.017248074070316918, 'koi_insol'),
#  (0.017199930683594808, 'koi_period_err2'),
#  (0.0157291444050664, 'koi_insol_err2'),
#  (0.015684242030411764, 'koi_time0bk'),
#  (0.015158939822249475, 'koi_depth_err1'),
#  (0.014777328331462745, 'koi_teq'),
#  (0.014454616930041117, 'koi_depth_err2'),
#  (0.013653963897941069, 'ra'),
#  (0.013328733230260698, 'dec'),
#  (0.013048214815115328, 'koi_srad_err1'),
#  (0.012743400024964362, 'koi_kepmag'),
#  (0.012573687523353062, 'koi_impact_err1'),
#  (0.012435225656871482, 'koi_impact_err2'),
#  (0.01119311212746617, 'koi_slogg_err2')]
