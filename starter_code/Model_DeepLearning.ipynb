# %%
import pandas as pd

df = pd.read_csv("exoplanet_data.csv")
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %%
df.shape
# Out:
# (6991, 41)

# %%
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %%
df.shape
# Out:
# (6991, 41)

# %%
# Set features. This will also be used as your x values.
# selected_features = df[['names', 'of', 'selected', 'features', 'here']]
X = df[['koi_fpflag_co', 
        'koi_fpflag_nt', 
        'koi_fpflag_ss', 
        'koi_model_snr',
        'koi_prad',
        'koi_fpflag_ec',
        'koi_prad_err2',
        'koi_steff_err2',
        'koi_steff_err1',
        'koi_duration_err1',
        'koi_duration_err2',
        'koi_prad_err1',
        'koi_time0bk_err1',
        'koi_time0bk_err2',
        'koi_duration',
        'koi_period',
        'koi_depth',
        'koi_period_err1',
        'koi_insol_err1',
        'koi_impact',
        'koi_period_err2',
        'koi_insol',
        'koi_teq',
        'koi_insol_err2',
        'koi_depth_err1',
        'koi_time0bk',
        'koi_depth_err2',
        'ra',
        'koi_srad_err1',
        'dec',
        'koi_impact_err1',
        'koi_kepmag',
        'koi_impact_err2',
        'koi_slogg_err2']]
y = df["koi_disposition"]
print(X.shape, y.shape)
# Out:
# (6991, 34) (6991,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
X_train.shape
# Out:
# (5243, 34)

# %%
# Scale your data
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Create model and add layers
modelDL = Sequential()
modelDL.add(Dense(units=100, activation='relu', input_dim=34))
modelDL.add(Dense(units=100, activation='relu'))
modelDL.add(Dense(units=3, activation='softmax'))

# Compile and fit the model
modelDL.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

modelDL.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_9 (Dense)              (None, 100)               3500
# _________________________________________________________________
# dense_10 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_11 (Dense)             (None, 3)                 303
# ...
# Total params: 13,903
# Trainable params: 13,903
# Non-trainable params: 0
# _________________________________________________________________

# %%
modelDL.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 164/164 - 0s - loss: 0.5662 - accuracy: 0.7259
# Epoch 2/100
# 164/164 - 0s - loss: 0.3800 - accuracy: 0.8058
# Epoch 3/100
# 164/164 - 0s - loss: 0.3662 - accuracy: 0.8173
# Epoch 4/100
# 164/164 - 0s - loss: 0.3539 - accuracy: 0.8255
# Epoch 5/100
# 164/164 - 0s - loss: 0.3470 - accuracy: 0.8293
# Epoch 6/100
# 164/164 - 0s - loss: 0.3413 - accuracy: 0.8375
# Epoch 7/100
# 164/164 - 0s - loss: 0.3336 - accuracy: 0.8388
# Epoch 8/100
# 164/164 - 0s - loss: 0.3280 - accuracy: 0.8476
# Epoch 9/100
# 164/164 - 0s - loss: 0.3231 - accuracy: 0.8465
# Epoch 10/100
# 164/164 - 0s - loss: 0.3231 - accuracy: 0.8529
# Epoch 11/100
# 164/164 - 0s - loss: 0.3157 - accuracy: 0.8568
# Epoch 12/100
# 164/164 - 0s - loss: 0.3107 - accuracy: 0.8623
# Epoch 13/100
# 164/164 - 0s - loss: 0.3153 - accuracy: 0.8568
# Epoch 14/100
# 164/164 - 0s - loss: 0.3072 - accuracy: 0.8638
# Epoch 15/100
# 164/164 - 0s - loss: 0.3070 - accuracy: 0.8640
# Epoch 16/100
# ...

# %%
model_loss, model_accuracy = modelDL.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2535 - accuracy: 0.9010
# Normal Neural Network - Loss: 0.2534621059894562, Accuracy: 0.9010297656059265

# %%
encoded_predictions = modelDL.predict_classes(X_test_scaled[:20])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)

# %%
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:20])}")
# Out:
# Predicted classes: ['CONFIRMED' 'FALSE POSITIVE' 'FALSE POSITIVE' 'CONFIRMED'
#  'FALSE POSITIVE' 'FALSE POSITIVE' 'FALSE POSITIVE' 'CONFIRMED'
#  'CONFIRMED' 'FALSE POSITIVE' 'CONFIRMED' 'FALSE POSITIVE'
#  'FALSE POSITIVE' 'CONFIRMED' 'CANDIDATE' 'CONFIRMED' 'FALSE POSITIVE'
#  'FALSE POSITIVE' 'CONFIRMED' 'CANDIDATE']
# Actual Labels: ['CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED', 'CANDIDATE', 'FALSE POSITIVE', 'CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CANDIDATE', 'CANDIDATE', 'CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED', 'CANDIDATE']

# %%
# save fitted model to file
import joblib
filename = 'Model_DeepLearning.sav'
joblib.dump(modelDL, filename)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-b676cdc73c36> in <module>
#       2 import joblib
#       3 filename = 'Model_DeepLearning.sav'
# ----> 4 joblib.dump(modelDL, filename)
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\joblib\numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     478     elif is_filename:
#     479         with open(filename, 'wb') as f:
# --> 480             NumpyPickler(f, protocol=protocol).dump(value)
#     481     else:
#     482         NumpyPickler(filename, protocol=protocol).dump(value)
#
# ~\anaconda3\envs\PythonAdv\lib\pickle.py in dump(self, obj)
#     407         if self.proto >= 4:
#     408             self.framer.start_framing()
# --> 409         self.save(obj)
#     410         self.write(STOP)
#     411         self.framer.end_framing()
#
# ...
