# %%
import pandas as pd

df = pd.read_csv("exoplanet_data.csv")
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
df.shape
# Out:
# (6991, 41)

# %%
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
df.shape
# Out:
# (6991, 41)

# %%
# Set features. This will also be used as your x values.
# selected_features = df[['names', 'of', 'selected', 'features', 'here']]
X = df[['koi_fpflag_co', 
        'koi_fpflag_nt', 
        'koi_fpflag_ss', 
        'koi_model_snr',
        'koi_prad',
        'koi_fpflag_ec',
        'koi_prad_err2',
        'koi_steff_err2',
        'koi_steff_err1',
        'koi_duration_err1',
        'koi_duration_err2',
        'koi_prad_err1',
        'koi_time0bk_err1',
        'koi_time0bk_err2',
        'koi_duration',
        'koi_period',
        'koi_depth',
        'koi_period_err1',
        'koi_insol_err1',
        'koi_impact',
        'koi_period_err2',
        'koi_insol',
        'koi_teq',
        'koi_insol_err2',
        'koi_depth_err1',
        'koi_time0bk',
        'koi_depth_err2',
        'ra',
        'koi_srad_err1',
        'dec',
        'koi_impact_err1',
        'koi_kepmag',
        'koi_impact_err2',
        'koi_slogg_err2']]
y = df["koi_disposition"]
print(X.shape, y.shape)
# Out:
# (6991, 34) (6991,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
X_train.shape
# Out:
# (5243, 34)

# %%
# Scale your data
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Create model and add layers
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=34))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=3, activation='softmax'))

# Compile and fit the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 100)               3500
# _________________________________________________________________
# dense_7 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_8 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 13,903
# Trainable params: 13,903
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 164/164 - 1s - loss: 0.5810 - accuracy: 0.7053
# Epoch 2/100
# 164/164 - 0s - loss: 0.3830 - accuracy: 0.8053
# Epoch 3/100
# 164/164 - 0s - loss: 0.3624 - accuracy: 0.8167
# Epoch 4/100
# 164/164 - 0s - loss: 0.3553 - accuracy: 0.8272
# Epoch 5/100
# 164/164 - 0s - loss: 0.3446 - accuracy: 0.8390
# Epoch 6/100
# 164/164 - 0s - loss: 0.3459 - accuracy: 0.8287
# Epoch 7/100
# 164/164 - 0s - loss: 0.3347 - accuracy: 0.8484
# Epoch 8/100
# 164/164 - 0s - loss: 0.3296 - accuracy: 0.8446
# Epoch 9/100
# 164/164 - 0s - loss: 0.3279 - accuracy: 0.8459
# Epoch 10/100
# 164/164 - 0s - loss: 0.3200 - accuracy: 0.8550
# Epoch 11/100
# 164/164 - 0s - loss: 0.3191 - accuracy: 0.8482
# Epoch 12/100
# 164/164 - 0s - loss: 0.3124 - accuracy: 0.8577
# Epoch 13/100
# 164/164 - 0s - loss: 0.3118 - accuracy: 0.8562
# Epoch 14/100
# 164/164 - 0s - loss: 0.3091 - accuracy: 0.8646
# Epoch 15/100
# 164/164 - 0s - loss: 0.3100 - accuracy: 0.8613
# Epoch 16/100
# 164/164 - 0s - loss: 0.3092 - accuracy: 0.8589
# Epoch 17/100
# 164/164 - 0s - loss: 0.3082 - accuracy: 0.8585
# Epoch 18/100
# 164/164 - 0s - loss: 0.2987 - accuracy: 0.8743
# Epoch 19/100
# 164/164 - 0s - loss: 0.2996 - accuracy: 0.8703
# Epoch 20/100
# 164/164 - 0s - loss: 0.2990 - accuracy: 0.8699
# Epoch 21/100
# 164/164 - 0s - loss: 0.2994 - accuracy: 0.8686
# Epoch 22/100
# 164/164 - 0s - loss: 0.2986 - accuracy: 0.8642
# Epoch 23/100
# 164/164 - 0s - loss: 0.2919 - accuracy: 0.8741
# Epoch 24/100
# 164/164 - 0s - loss: 0.2880 - accuracy: 0.8772
# Epoch 25/100
# 164/164 - 0s - loss: 0.2921 - accuracy: 0.8665
# Epoch 26/100
# 164/164 - 0s - loss: 0.2875 - accuracy: 0.8751
# Epoch 27/100
# 164/164 - 0s - loss: 0.2836 - accuracy: 0.8770
# Epoch 28/100
# 164/164 - 0s - loss: 0.2866 - accuracy: 0.8749
# Epoch 29/100
# 164/164 - 0s - loss: 0.2831 - accuracy: 0.8743
# Epoch 30/100
# 164/164 - 0s - loss: 0.2842 - accuracy: 0.8762
# Epoch 31/100
# 164/164 - 0s - loss: 0.2856 - accuracy: 0.8745
# Epoch 32/100
# 164/164 - 0s - loss: 0.2783 - accuracy: 0.8793
# Epoch 33/100
# 164/164 - 0s - loss: 0.2845 - accuracy: 0.8766
# Epoch 34/100
# 164/164 - 0s - loss: 0.2794 - accuracy: 0.8793
# Epoch 35/100
# 164/164 - 0s - loss: 0.2785 - accuracy: 0.8833
# Epoch 36/100
# 164/164 - 0s - loss: 0.2718 - accuracy: 0.8806
# Epoch 37/100
# 164/164 - 0s - loss: 0.2777 - accuracy: 0.8835
# Epoch 38/100
# 164/164 - 0s - loss: 0.2753 - accuracy: 0.8816
# Epoch 39/100
# 164/164 - 0s - loss: 0.2789 - accuracy: 0.8760
# Epoch 40/100
# 164/164 - 0s - loss: 0.2765 - accuracy: 0.8816
# Epoch 41/100
# 164/164 - 0s - loss: 0.2724 - accuracy: 0.8798
# Epoch 42/100
# 164/164 - 0s - loss: 0.2743 - accuracy: 0.8751
# Epoch 43/100
# 164/164 - 0s - loss: 0.2692 - accuracy: 0.8842
# Epoch 44/100
# 164/164 - 0s - loss: 0.2671 - accuracy: 0.8804
# Epoch 45/100
# 164/164 - 0s - loss: 0.2782 - accuracy: 0.8774
# Epoch 46/100
# 164/164 - 0s - loss: 0.2763 - accuracy: 0.8772
# Epoch 47/100
# 164/164 - 0s - loss: 0.2674 - accuracy: 0.8858
# Epoch 48/100
# 164/164 - 0s - loss: 0.2657 - accuracy: 0.8848
# Epoch 49/100
# 164/164 - 0s - loss: 0.2677 - accuracy: 0.8808
# Epoch 50/100
# 164/164 - 0s - loss: 0.2656 - accuracy: 0.8829
# Epoch 51/100
# 164/164 - 0s - loss: 0.2630 - accuracy: 0.8842
# Epoch 52/100
# 164/164 - 0s - loss: 0.2640 - accuracy: 0.8852
# Epoch 53/100
# 164/164 - 0s - loss: 0.2595 - accuracy: 0.8846
# Epoch 54/100
# 164/164 - 0s - loss: 0.2589 - accuracy: 0.8863
# Epoch 55/100
# 164/164 - 0s - loss: 0.2560 - accuracy: 0.8882
# Epoch 56/100
# 164/164 - 0s - loss: 0.2578 - accuracy: 0.8884
# Epoch 57/100
# 164/164 - 0s - loss: 0.2567 - accuracy: 0.8882
# Epoch 58/100
# 164/164 - 0s - loss: 0.2565 - accuracy: 0.8886
# Epoch 59/100
# 164/164 - 0s - loss: 0.2547 - accuracy: 0.8879
# Epoch 60/100
# 164/164 - 0s - loss: 0.2566 - accuracy: 0.8884
# Epoch 61/100
# 164/164 - 0s - loss: 0.2544 - accuracy: 0.8907
# Epoch 62/100
# 164/164 - 0s - loss: 0.2541 - accuracy: 0.8869
# Epoch 63/100
# 164/164 - 0s - loss: 0.2573 - accuracy: 0.8852
# Epoch 64/100
# 164/164 - 0s - loss: 0.2523 - accuracy: 0.8898
# Epoch 65/100
# 164/164 - 0s - loss: 0.2522 - accuracy: 0.8896
# Epoch 66/100
# 164/164 - 0s - loss: 0.2483 - accuracy: 0.8938
# Epoch 67/100
# 164/164 - 0s - loss: 0.2542 - accuracy: 0.8882
# Epoch 68/100
# 164/164 - 0s - loss: 0.2469 - accuracy: 0.8947
# Epoch 69/100
# 164/164 - 0s - loss: 0.2591 - accuracy: 0.8838
# Epoch 70/100
# 164/164 - 0s - loss: 0.2496 - accuracy: 0.8865
# Epoch 71/100
# 164/164 - 0s - loss: 0.2481 - accuracy: 0.8909
# Epoch 72/100
# 164/164 - 0s - loss: 0.2524 - accuracy: 0.8905
# Epoch 73/100
# 164/164 - 0s - loss: 0.2461 - accuracy: 0.8920
# Epoch 74/100
# 164/164 - 0s - loss: 0.2447 - accuracy: 0.8919
# Epoch 75/100
# 164/164 - 0s - loss: 0.2457 - accuracy: 0.8922
# Epoch 76/100
# 164/164 - 0s - loss: 0.2470 - accuracy: 0.8873
# Epoch 77/100
# 164/164 - 0s - loss: 0.2513 - accuracy: 0.8856
# Epoch 78/100
# 164/164 - 0s - loss: 0.2479 - accuracy: 0.8892
# Epoch 79/100
# 164/164 - 0s - loss: 0.2442 - accuracy: 0.8949
# Epoch 80/100
# 164/164 - 0s - loss: 0.2491 - accuracy: 0.8852
# Epoch 81/100
# 164/164 - 0s - loss: 0.2422 - accuracy: 0.8928
# Epoch 82/100
# 164/164 - 0s - loss: 0.2437 - accuracy: 0.8879
# Epoch 83/100
# 164/164 - 0s - loss: 0.2475 - accuracy: 0.8907
# Epoch 84/100
# 164/164 - 0s - loss: 0.2432 - accuracy: 0.8905
# Epoch 85/100
# 164/164 - 0s - loss: 0.2415 - accuracy: 0.8915
# Epoch 86/100
# 164/164 - 0s - loss: 0.2431 - accuracy: 0.8917
# Epoch 87/100
# 164/164 - 0s - loss: 0.2502 - accuracy: 0.8854
# Epoch 88/100
# 164/164 - 0s - loss: 0.2376 - accuracy: 0.8938
# Epoch 89/100
# 164/164 - 0s - loss: 0.2431 - accuracy: 0.8863
# Epoch 90/100
# 164/164 - 0s - loss: 0.2466 - accuracy: 0.8907
# Epoch 91/100
# 164/164 - 0s - loss: 0.2405 - accuracy: 0.8949
# Epoch 92/100
# 164/164 - 0s - loss: 0.2404 - accuracy: 0.8899
# Epoch 93/100
# 164/164 - 0s - loss: 0.2381 - accuracy: 0.8930
# Epoch 94/100
# 164/164 - 0s - loss: 0.2346 - accuracy: 0.8961
# Epoch 95/100
# 164/164 - 0s - loss: 0.2445 - accuracy: 0.8865
# Epoch 96/100
# 164/164 - 0s - loss: 0.2380 - accuracy: 0.8930
# Epoch 97/100
# 164/164 - 0s - loss: 0.2374 - accuracy: 0.8943
# Epoch 98/100
# 164/164 - 0s - loss: 0.2334 - accuracy: 0.8961
# Epoch 99/100
# 164/164 - 0s - loss: 0.2355 - accuracy: 0.8930
# Epoch 100/100
# 164/164 - 0s - loss: 0.2374 - accuracy: 0.8924

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2418 - accuracy: 0.9010
# Normal Neural Network - Loss: 0.24180708825588226, Accuracy: 0.9010297656059265

# %%
encoded_predictions = model.predict_classes(X_test_scaled[:20])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)
# Out:
# C:\Users\jcg\anaconda3\envs\PythonAdv\lib\site-packages\tensorflow\python\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:20])}")
# Out:
# Predicted classes: ['CONFIRMED' 'FALSE POSITIVE' 'FALSE POSITIVE' 'CONFIRMED'
#  'FALSE POSITIVE' 'FALSE POSITIVE' 'FALSE POSITIVE' 'CANDIDATE'
#  'CONFIRMED' 'FALSE POSITIVE' 'CONFIRMED' 'FALSE POSITIVE'
#  'FALSE POSITIVE' 'CANDIDATE' 'CANDIDATE' 'CONFIRMED' 'FALSE POSITIVE'
#  'FALSE POSITIVE' 'CONFIRMED' 'CANDIDATE']
# Actual Labels: ['CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED', 'CANDIDATE', 'FALSE POSITIVE', 'CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CANDIDATE', 'CANDIDATE', 'CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED', 'CANDIDATE']

# %%
# save fitted model to file
import joblib
filename = 'Model_DeepLearning.sav'
joblib.dump(model, filename)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-787c921ec65d> in <module>
#       2 import joblib
#       3 filename = 'Model_DeepLearning.sav'
# ----> 4 joblib.dump(model, filename)
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\joblib\numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     478     elif is_filename:
#     479         with open(filename, 'wb') as f:
# --> 480             NumpyPickler(f, protocol=protocol).dump(value)
#     481     else:
#     482         NumpyPickler(filename, protocol=protocol).dump(value)
#
# ~\anaconda3\envs\PythonAdv\lib\pickle.py in dump(self, obj)
#     407         if self.proto >= 4:
#     408             self.framer.start_framing()
# --> 409         self.save(obj)
#     410         self.write(STOP)
#     411         self.framer.end_framing()
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\anaconda3\envs\PythonAdv\lib\pickle.py in save(self, obj, save_persistent_id)
#     519
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#     523     def persistent_id(self, obj):
#
# ~\anaconda3\envs\PythonAdv\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     632
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#     636
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\anaconda3\envs\PythonAdv\lib\pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~\anaconda3\envs\PythonAdv\lib\pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# ~\anaconda3\envs\PythonAdv\lib\pickle.py in _batch_setitems(self, items)
#     845                 for k, v in tmp:
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#     849             elif n:
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\anaconda3\envs\PythonAdv\lib\pickle.py in save(self, obj, save_persistent_id)
#     519
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#     523     def persistent_id(self, obj):
#
# ~\anaconda3\envs\PythonAdv\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     632
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#     636
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\anaconda3\envs\PythonAdv\lib\pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~\anaconda3\envs\PythonAdv\lib\pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# ~\anaconda3\envs\PythonAdv\lib\pickle.py in _batch_setitems(self, items)
#     845                 for k, v in tmp:
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#     849             elif n:
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\anaconda3\envs\PythonAdv\lib\pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~\anaconda3\envs\PythonAdv\lib\pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# ~\anaconda3\envs\PythonAdv\lib\pickle.py in _batch_setitems(self, items)
#     844                 write(MARK)
#     845                 for k, v in tmp:
# --> 846                     save(k)
#     847                     save(v)
#     848                 write(SETITEMS)
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\anaconda3\envs\PythonAdv\lib\pickle.py in save(self, obj, save_persistent_id)
#     494             reduce = getattr(obj, "__reduce_ex__", None)
#     495             if reduce is not None:
# --> 496                 rv = reduce(self.proto)
#     497             else:
#     498                 reduce = getattr(obj, "__reduce__", None)
#
# TypeError: can't pickle weakref objects
