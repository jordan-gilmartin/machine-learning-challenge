# %%
import pandas as pd

df = pd.read_csv("exoplanet_data.csv")
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
df.shape
# Out:
# (6991, 41)

# %%
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
df.shape
# Out:
# (6991, 41)

# %%
# Set features. This will also be used as your x values.
# selected_features = df[['names', 'of', 'selected', 'features', 'here']]
X = df[['koi_fpflag_co', 
        'koi_fpflag_nt', 
        'koi_fpflag_ss', 
        'koi_model_snr',
        'koi_prad',
        'koi_fpflag_ec',
        'koi_prad_err2',
        'koi_steff_err2',
        'koi_steff_err1',
        'koi_duration_err1',
        'koi_duration_err2',
        'koi_prad_err1',
        'koi_time0bk_err1',
        'koi_time0bk_err2',
        'koi_duration',
        'koi_period',
        'koi_depth',
        'koi_period_err1',
        'koi_insol_err1',
        'koi_impact',
        'koi_period_err2',
        'koi_insol',
        'koi_teq',
        'koi_insol_err2',
        'koi_depth_err1',
        'koi_time0bk',
        'koi_depth_err2',
        'ra',
        'koi_srad_err1',
        'dec',
        'koi_impact_err1',
        'koi_kepmag',
        'koi_impact_err2',
        'koi_slogg_err2']]
y = df["koi_disposition"]
print(X.shape, y.shape)
# Out:
# (6991, 34) (6991,)

# %%
feature_names = X.columns

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
X_train.shape
# Out:
# (5243, 34)

# %%
# Scale your data
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Create model and add layers
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=34))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=3, activation='softmax'))

# Compile and fit the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               3500
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 13,903
# Trainable params: 13,903
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 164/164 - 0s - loss: 0.2493 - accuracy: 0.8909
# Epoch 2/100
# 164/164 - 0s - loss: 0.2532 - accuracy: 0.8856
# Epoch 3/100
# 164/164 - 0s - loss: 0.2498 - accuracy: 0.8886
# Epoch 4/100
# 164/164 - 0s - loss: 0.2507 - accuracy: 0.8833
# Epoch 5/100
# 164/164 - 0s - loss: 0.2580 - accuracy: 0.8808
# Epoch 6/100
# 164/164 - 0s - loss: 0.2501 - accuracy: 0.8880
# Epoch 7/100
# 164/164 - 0s - loss: 0.2423 - accuracy: 0.8930
# Epoch 8/100
# 164/164 - 0s - loss: 0.2483 - accuracy: 0.8899
# Epoch 9/100
# 164/164 - 0s - loss: 0.2449 - accuracy: 0.8901
# Epoch 10/100
# 164/164 - 0s - loss: 0.2433 - accuracy: 0.8899
# Epoch 11/100
# 164/164 - 0s - loss: 0.2418 - accuracy: 0.8955
# Epoch 12/100
# 164/164 - 0s - loss: 0.2422 - accuracy: 0.8947
# Epoch 13/100
# 164/164 - 0s - loss: 0.2440 - accuracy: 0.8890
# Epoch 14/100
# 164/164 - 0s - loss: 0.2422 - accuracy: 0.8924
# Epoch 15/100
# 164/164 - 0s - loss: 0.2374 - accuracy: 0.8959
# Epoch 16/100
# 164/164 - 0s - loss: 0.2434 - accuracy: 0.8922
# Epoch 17/100
# 164/164 - 0s - loss: 0.2416 - accuracy: 0.8953
# Epoch 18/100
# 164/164 - 0s - loss: 0.2385 - accuracy: 0.8928
# Epoch 19/100
# 164/164 - 0s - loss: 0.2382 - accuracy: 0.8932
# Epoch 20/100
# 164/164 - 0s - loss: 0.2363 - accuracy: 0.8953
# Epoch 21/100
# 164/164 - 0s - loss: 0.2434 - accuracy: 0.8907
# Epoch 22/100
# 164/164 - 0s - loss: 0.2400 - accuracy: 0.8936
# Epoch 23/100
# 164/164 - 0s - loss: 0.2373 - accuracy: 0.8945
# Epoch 24/100
# 164/164 - 0s - loss: 0.2417 - accuracy: 0.8907
# Epoch 25/100
# 164/164 - 0s - loss: 0.2373 - accuracy: 0.8959
# Epoch 26/100
# 164/164 - 0s - loss: 0.2418 - accuracy: 0.8926
# Epoch 27/100
# 164/164 - 0s - loss: 0.2363 - accuracy: 0.8978
# Epoch 28/100
# 164/164 - 0s - loss: 0.2319 - accuracy: 0.8934
# Epoch 29/100
# 164/164 - 0s - loss: 0.2384 - accuracy: 0.8955
# Epoch 30/100
# 164/164 - 0s - loss: 0.2346 - accuracy: 0.8932
# Epoch 31/100
# 164/164 - 0s - loss: 0.2332 - accuracy: 0.8955
# Epoch 32/100
# 164/164 - 0s - loss: 0.2399 - accuracy: 0.8930
# Epoch 33/100
# 164/164 - 0s - loss: 0.2293 - accuracy: 0.8970
# Epoch 34/100
# 164/164 - 0s - loss: 0.2276 - accuracy: 0.9002
# Epoch 35/100
# 164/164 - 0s - loss: 0.2324 - accuracy: 0.8970
# Epoch 36/100
# 164/164 - 0s - loss: 0.2349 - accuracy: 0.8968
# Epoch 37/100
# 164/164 - 0s - loss: 0.2355 - accuracy: 0.8949
# Epoch 38/100
# 164/164 - 0s - loss: 0.2335 - accuracy: 0.8964
# Epoch 39/100
# 164/164 - 0s - loss: 0.2321 - accuracy: 0.8968
# Epoch 40/100
# 164/164 - 0s - loss: 0.2267 - accuracy: 0.8989
# Epoch 41/100
# 164/164 - 0s - loss: 0.2348 - accuracy: 0.8949
# Epoch 42/100
# 164/164 - 0s - loss: 0.2296 - accuracy: 0.8972
# Epoch 43/100
# 164/164 - 0s - loss: 0.2329 - accuracy: 0.8974
# Epoch 44/100
# 164/164 - 0s - loss: 0.2327 - accuracy: 0.8945
# Epoch 45/100
# 164/164 - 0s - loss: 0.2301 - accuracy: 0.9010
# Epoch 46/100
# 164/164 - 0s - loss: 0.2289 - accuracy: 0.8989
# Epoch 47/100
# 164/164 - 0s - loss: 0.2279 - accuracy: 0.8976
# Epoch 48/100
# 164/164 - 0s - loss: 0.2275 - accuracy: 0.8972
# Epoch 49/100
# 164/164 - 0s - loss: 0.2294 - accuracy: 0.8915
# Epoch 50/100
# 164/164 - 0s - loss: 0.2238 - accuracy: 0.9002
# Epoch 51/100
# 164/164 - 0s - loss: 0.2280 - accuracy: 0.8983
# Epoch 52/100
# 164/164 - 0s - loss: 0.2312 - accuracy: 0.8997
# Epoch 53/100
# 164/164 - 0s - loss: 0.2250 - accuracy: 0.9044
# Epoch 54/100
# 164/164 - 0s - loss: 0.2212 - accuracy: 0.9012
# Epoch 55/100
# 164/164 - 0s - loss: 0.2211 - accuracy: 0.9022
# Epoch 56/100
# 164/164 - 0s - loss: 0.2246 - accuracy: 0.8972
# Epoch 57/100
# 164/164 - 0s - loss: 0.2218 - accuracy: 0.9010
# Epoch 58/100
# 164/164 - 0s - loss: 0.2270 - accuracy: 0.9004
# Epoch 59/100
# 164/164 - 0s - loss: 0.2234 - accuracy: 0.9010
# Epoch 60/100
# 164/164 - 0s - loss: 0.2244 - accuracy: 0.8997
# Epoch 61/100
# 164/164 - 0s - loss: 0.2208 - accuracy: 0.9035
# Epoch 62/100
# 164/164 - 0s - loss: 0.2186 - accuracy: 0.9035
# Epoch 63/100
# 164/164 - 0s - loss: 0.2190 - accuracy: 0.9012
# Epoch 64/100
# 164/164 - 0s - loss: 0.2189 - accuracy: 0.9046
# Epoch 65/100
# 164/164 - 0s - loss: 0.2207 - accuracy: 0.9004
# Epoch 66/100
# 164/164 - 0s - loss: 0.2206 - accuracy: 0.9037
# Epoch 67/100
# 164/164 - 0s - loss: 0.2241 - accuracy: 0.9012
# Epoch 68/100
# 164/164 - 0s - loss: 0.2216 - accuracy: 0.9006
# Epoch 69/100
# 164/164 - 0s - loss: 0.2176 - accuracy: 0.9025
# Epoch 70/100
# 164/164 - 0s - loss: 0.2173 - accuracy: 0.9043
# Epoch 71/100
# 164/164 - 0s - loss: 0.2224 - accuracy: 0.9029
# Epoch 72/100
# 164/164 - 0s - loss: 0.2152 - accuracy: 0.9020
# Epoch 73/100
# 164/164 - 0s - loss: 0.2145 - accuracy: 0.9043
# Epoch 74/100
# 164/164 - 0s - loss: 0.2197 - accuracy: 0.9025
# Epoch 75/100
# 164/164 - 0s - loss: 0.2162 - accuracy: 0.9046
# Epoch 76/100
# 164/164 - 0s - loss: 0.2128 - accuracy: 0.9035
# Epoch 77/100
# 164/164 - 0s - loss: 0.2225 - accuracy: 0.8991
# Epoch 78/100
# 164/164 - 0s - loss: 0.2170 - accuracy: 0.9014
# Epoch 79/100
# 164/164 - 0s - loss: 0.2138 - accuracy: 0.9043
# Epoch 80/100
# 164/164 - 0s - loss: 0.2134 - accuracy: 0.9073
# Epoch 81/100
# 164/164 - 0s - loss: 0.2103 - accuracy: 0.9092
# Epoch 82/100
# 164/164 - 0s - loss: 0.2152 - accuracy: 0.9037
# Epoch 83/100
# 164/164 - 0s - loss: 0.2144 - accuracy: 0.9014
# Epoch 84/100
# 164/164 - 0s - loss: 0.2147 - accuracy: 0.9027
# Epoch 85/100
# 164/164 - 0s - loss: 0.2107 - accuracy: 0.9039
# Epoch 86/100
# 164/164 - 0s - loss: 0.2127 - accuracy: 0.9048
# Epoch 87/100
# 164/164 - 0s - loss: 0.2139 - accuracy: 0.9041
# Epoch 88/100
# 164/164 - 0s - loss: 0.2100 - accuracy: 0.9056
# Epoch 89/100
# 164/164 - 0s - loss: 0.2216 - accuracy: 0.8999
# Epoch 90/100
# 164/164 - 0s - loss: 0.2123 - accuracy: 0.9060
# Epoch 91/100
# 164/164 - 0s - loss: 0.2083 - accuracy: 0.9073
# Epoch 92/100
# 164/164 - 0s - loss: 0.2119 - accuracy: 0.9062
# Epoch 93/100
# 164/164 - 0s - loss: 0.2090 - accuracy: 0.9029
# Epoch 94/100
# 164/164 - 0s - loss: 0.2183 - accuracy: 0.9022
# Epoch 95/100
# 164/164 - 0s - loss: 0.2073 - accuracy: 0.9086
# Epoch 96/100
# 164/164 - 0s - loss: 0.2069 - accuracy: 0.9077
# Epoch 97/100
# 164/164 - 0s - loss: 0.2083 - accuracy: 0.9029
# Epoch 98/100
# 164/164 - 0s - loss: 0.2053 - accuracy: 0.9107
# Epoch 99/100
# 164/164 - 0s - loss: 0.2074 - accuracy: 0.9081
# Epoch 100/100
# 164/164 - 0s - loss: 0.2120 - accuracy: 0.9029

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2649 - accuracy: 0.9010
# Normal Neural Network - Loss: 0.2648676931858063, Accuracy: 0.9010297656059265

# %%
encoded_predictions = model.predict_classes(X_test_scaled[:20])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)
# Out:
# C:\Users\jcg\anaconda3\envs\PythonAdv\lib\site-packages\tensorflow\python\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:20])}")
# Out:
# Predicted classes: ['CONFIRMED' 'FALSE POSITIVE' 'FALSE POSITIVE' 'CONFIRMED'
#  'FALSE POSITIVE' 'FALSE POSITIVE' 'FALSE POSITIVE' 'CANDIDATE'
#  'CONFIRMED' 'FALSE POSITIVE' 'CONFIRMED' 'FALSE POSITIVE'
#  'FALSE POSITIVE' 'CANDIDATE' 'CANDIDATE' 'CONFIRMED' 'FALSE POSITIVE'
#  'FALSE POSITIVE' 'CONFIRMED' 'CANDIDATE']
# Actual Labels: ['CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED', 'CANDIDATE', 'FALSE POSITIVE', 'CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CANDIDATE', 'CANDIDATE', 'CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED', 'CANDIDATE']
