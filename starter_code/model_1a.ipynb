# %%
import pandas as pd

df = pd.read_csv("exoplanet_data.csv")
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
df.shape
# Out:
# (6991, 41)

# %%
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
df.shape
# Out:
# (6991, 41)

# %%
# Set features. This will also be used as your x values.
# selected_features = df[['names', 'of', 'selected', 'features', 'here']]
X = df[['koi_fpflag_co', 
        'koi_fpflag_nt', 
        'koi_fpflag_ss', 
        'koi_model_snr',
        'koi_prad',
        'koi_fpflag_ec',
        'koi_prad_err2',
        'koi_steff_err2',
        'koi_steff_err1',
        'koi_duration_err1',
        'koi_duration_err2',
        'koi_prad_err1',
        'koi_time0bk_err1',
        'koi_time0bk_err2',
        'koi_duration',
        'koi_period',
        'koi_depth',
        'koi_period_err1',
        'koi_insol_err1',
        'koi_impact',
        'koi_period_err2',
        'koi_insol',
        'koi_teq',
        'koi_insol_err2',
        'koi_depth_err1',
        'koi_time0bk',
        'koi_depth_err2',
        'ra',
        'koi_srad_err1',
        'dec',
        'koi_impact_err1',
        'koi_kepmag',
        'koi_impact_err2',
        'koi_slogg_err2']]
y = df["koi_disposition"]
print(X.shape, y.shape)
# Out:
# (6991, 34) (6991,)

# %%
feature_names = X.columns

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X_train.shape
# Out:
# (5243, 34)

# %%
# Scale your data
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Create model and add layers
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=34))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=3, activation='softmax'))

# Compile and fit the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 100)               3500
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 13,903
# Trainable params: 13,903
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 164/164 - 0s - loss: 0.5488 - accuracy: 0.7160
# Epoch 2/100
# 164/164 - 0s - loss: 0.3745 - accuracy: 0.7988
# Epoch 3/100
# 164/164 - 0s - loss: 0.3492 - accuracy: 0.8194
# Epoch 4/100
# 164/164 - 0s - loss: 0.3388 - accuracy: 0.8407
# Epoch 5/100
# 164/164 - 0s - loss: 0.3319 - accuracy: 0.8411
# Epoch 6/100
# 164/164 - 0s - loss: 0.3237 - accuracy: 0.8449
# Epoch 7/100
# 164/164 - 0s - loss: 0.3198 - accuracy: 0.8482
# Epoch 8/100
# 164/164 - 0s - loss: 0.3151 - accuracy: 0.8533
# Epoch 9/100
# 164/164 - 0s - loss: 0.3055 - accuracy: 0.8636
# Epoch 10/100
# 164/164 - 0s - loss: 0.3070 - accuracy: 0.8602
# Epoch 11/100
# 164/164 - 0s - loss: 0.3023 - accuracy: 0.8636
# Epoch 12/100
# 164/164 - 0s - loss: 0.2960 - accuracy: 0.8682
# Epoch 13/100
# 164/164 - 0s - loss: 0.2958 - accuracy: 0.8720
# Epoch 14/100
# 164/164 - 0s - loss: 0.3002 - accuracy: 0.8684
# Epoch 15/100
# 164/164 - 0s - loss: 0.2934 - accuracy: 0.8693
# Epoch 16/100
# 164/164 - 0s - loss: 0.2906 - accuracy: 0.8693
# Epoch 17/100
# 164/164 - 0s - loss: 0.2911 - accuracy: 0.8692
# Epoch 18/100
# 164/164 - 0s - loss: 0.2891 - accuracy: 0.8735
# Epoch 19/100
# 164/164 - 0s - loss: 0.2886 - accuracy: 0.8724
# Epoch 20/100
# 164/164 - 0s - loss: 0.2811 - accuracy: 0.8777
# Epoch 21/100
# 164/164 - 0s - loss: 0.2810 - accuracy: 0.8789
# Epoch 22/100
# 164/164 - 0s - loss: 0.2818 - accuracy: 0.8743
# Epoch 23/100
# 164/164 - 0s - loss: 0.2779 - accuracy: 0.8795
# Epoch 24/100
# 164/164 - 0s - loss: 0.2787 - accuracy: 0.8772
# Epoch 25/100
# 164/164 - 0s - loss: 0.2757 - accuracy: 0.8783
# Epoch 26/100
# 164/164 - 0s - loss: 0.2788 - accuracy: 0.8711
# Epoch 27/100
# 164/164 - 0s - loss: 0.2761 - accuracy: 0.8770
# Epoch 28/100
# 164/164 - 0s - loss: 0.2690 - accuracy: 0.8848
# Epoch 29/100
# 164/164 - 0s - loss: 0.2694 - accuracy: 0.8844
# Epoch 30/100
# 164/164 - 0s - loss: 0.2667 - accuracy: 0.8859
# Epoch 31/100
# 164/164 - 0s - loss: 0.2775 - accuracy: 0.8795
# Epoch 32/100
# 164/164 - 0s - loss: 0.2678 - accuracy: 0.8816
# Epoch 33/100
# 164/164 - 0s - loss: 0.2692 - accuracy: 0.8791
# Epoch 34/100
# 164/164 - 0s - loss: 0.2735 - accuracy: 0.8806
# Epoch 35/100
# 164/164 - 0s - loss: 0.2675 - accuracy: 0.8802
# Epoch 36/100
# 164/164 - 0s - loss: 0.2612 - accuracy: 0.8877
# Epoch 37/100
# 164/164 - 0s - loss: 0.2629 - accuracy: 0.8884
# Epoch 38/100
# 164/164 - 0s - loss: 0.2638 - accuracy: 0.8859
# Epoch 39/100
# 164/164 - 0s - loss: 0.2708 - accuracy: 0.8796
# Epoch 40/100
# 164/164 - 0s - loss: 0.2600 - accuracy: 0.8842
# Epoch 41/100
# 164/164 - 0s - loss: 0.2651 - accuracy: 0.8791
# Epoch 42/100
# 164/164 - 0s - loss: 0.2584 - accuracy: 0.8886
# Epoch 43/100
# 164/164 - 0s - loss: 0.2576 - accuracy: 0.8894
# Epoch 44/100
# 164/164 - 0s - loss: 0.2550 - accuracy: 0.8879
# Epoch 45/100
# 164/164 - 0s - loss: 0.2574 - accuracy: 0.8896
# Epoch 46/100
# 164/164 - 0s - loss: 0.2581 - accuracy: 0.8858
# Epoch 47/100
# 164/164 - 0s - loss: 0.2573 - accuracy: 0.8859
# Epoch 48/100
# 164/164 - 0s - loss: 0.2543 - accuracy: 0.8882
# Epoch 49/100
# 164/164 - 0s - loss: 0.2549 - accuracy: 0.8888
# Epoch 50/100
# 164/164 - 0s - loss: 0.2594 - accuracy: 0.8859
# Epoch 51/100
# 164/164 - 0s - loss: 0.2511 - accuracy: 0.8861
# Epoch 52/100
# 164/164 - 0s - loss: 0.2570 - accuracy: 0.8858
# Epoch 53/100
# 164/164 - 0s - loss: 0.2544 - accuracy: 0.8865
# Epoch 54/100
# 164/164 - 0s - loss: 0.2491 - accuracy: 0.8896
# Epoch 55/100
# 164/164 - 0s - loss: 0.2529 - accuracy: 0.8901
# Epoch 56/100
# 164/164 - 0s - loss: 0.2502 - accuracy: 0.8880
# Epoch 57/100
# 164/164 - 0s - loss: 0.2471 - accuracy: 0.8896
# Epoch 58/100
# 164/164 - 0s - loss: 0.2514 - accuracy: 0.8879
# Epoch 59/100
# 164/164 - 0s - loss: 0.2437 - accuracy: 0.8953
# Epoch 60/100
# 164/164 - 0s - loss: 0.2494 - accuracy: 0.8888
# Epoch 61/100
# 164/164 - 0s - loss: 0.2472 - accuracy: 0.8899
# Epoch 62/100
# 164/164 - 0s - loss: 0.2452 - accuracy: 0.8888
# Epoch 63/100
# 164/164 - 0s - loss: 0.2408 - accuracy: 0.8959
# Epoch 64/100
# 164/164 - 0s - loss: 0.2433 - accuracy: 0.8919
# Epoch 65/100
# 164/164 - 0s - loss: 0.2452 - accuracy: 0.8888
# Epoch 66/100
# 164/164 - 0s - loss: 0.2446 - accuracy: 0.8884
# Epoch 67/100
# 164/164 - 0s - loss: 0.2421 - accuracy: 0.8947
# Epoch 68/100
# 164/164 - 0s - loss: 0.2398 - accuracy: 0.8917
# Epoch 69/100
# 164/164 - 0s - loss: 0.2383 - accuracy: 0.8953
# Epoch 70/100
# 164/164 - 0s - loss: 0.2418 - accuracy: 0.8894
# Epoch 71/100
# 164/164 - 0s - loss: 0.2399 - accuracy: 0.8922
# Epoch 72/100
# 164/164 - 0s - loss: 0.2440 - accuracy: 0.8898
# Epoch 73/100
# 164/164 - 0s - loss: 0.2410 - accuracy: 0.8936
# Epoch 74/100
# 164/164 - 0s - loss: 0.2346 - accuracy: 0.8972
# Epoch 75/100
# 164/164 - 0s - loss: 0.2390 - accuracy: 0.8924
# Epoch 76/100
# 164/164 - 0s - loss: 0.2451 - accuracy: 0.8890
# Epoch 77/100
# 164/164 - 0s - loss: 0.2396 - accuracy: 0.8922
# Epoch 78/100
# 164/164 - 0s - loss: 0.2336 - accuracy: 0.8970
# Epoch 79/100
# 164/164 - 0s - loss: 0.2379 - accuracy: 0.8917
# Epoch 80/100
# 164/164 - 0s - loss: 0.2351 - accuracy: 0.8983
# Epoch 81/100
# 164/164 - 0s - loss: 0.2362 - accuracy: 0.8922
# Epoch 82/100
# 164/164 - 0s - loss: 0.2378 - accuracy: 0.8940
# Epoch 83/100
# 164/164 - 0s - loss: 0.2321 - accuracy: 0.8957
# Epoch 84/100
# 164/164 - 0s - loss: 0.2398 - accuracy: 0.8924
# Epoch 85/100
# 164/164 - 0s - loss: 0.2331 - accuracy: 0.8968
# Epoch 86/100
# 164/164 - 0s - loss: 0.2344 - accuracy: 0.8951
# Epoch 87/100
# 164/164 - 0s - loss: 0.2298 - accuracy: 0.8966
# Epoch 88/100
# 164/164 - 0s - loss: 0.2272 - accuracy: 0.8966
# Epoch 89/100
# 164/164 - 0s - loss: 0.2349 - accuracy: 0.8947
# Epoch 90/100
# 164/164 - 0s - loss: 0.2293 - accuracy: 0.8959
# Epoch 91/100
# 164/164 - 0s - loss: 0.2285 - accuracy: 0.8968
# Epoch 92/100
# 164/164 - 0s - loss: 0.2288 - accuracy: 0.9014
# Epoch 93/100
# 164/164 - 0s - loss: 0.2296 - accuracy: 0.8995
# Epoch 94/100
# 164/164 - 0s - loss: 0.2315 - accuracy: 0.8955
# Epoch 95/100
# 164/164 - 0s - loss: 0.2288 - accuracy: 0.8989
# Epoch 96/100
# 164/164 - 0s - loss: 0.2288 - accuracy: 0.8940
# Epoch 97/100
# 164/164 - 0s - loss: 0.2265 - accuracy: 0.9001
# Epoch 98/100
# 164/164 - 0s - loss: 0.2365 - accuracy: 0.8920
# Epoch 99/100
# 164/164 - 0s - loss: 0.2281 - accuracy: 0.8985
# Epoch 100/100
# 164/164 - 0s - loss: 0.2272 - accuracy: 0.9001

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2657 - accuracy: 0.8890
# Normal Neural Network - Loss: 0.2656776010990143, Accuracy: 0.8890160322189331

# %%
encoded_predictions = model.predict_classes(X_test_scaled[:20])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)
# Out:
# C:\Users\jcg\anaconda3\envs\PythonAdv\lib\site-packages\tensorflow\python\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:20])}")
# Out:
# Predicted classes: ['CONFIRMED' 'FALSE POSITIVE' 'FALSE POSITIVE' 'CONFIRMED'
#  'FALSE POSITIVE' 'FALSE POSITIVE' 'FALSE POSITIVE' 'CANDIDATE'
#  'CONFIRMED' 'FALSE POSITIVE' 'CONFIRMED' 'FALSE POSITIVE'
#  'FALSE POSITIVE' 'CANDIDATE' 'CANDIDATE' 'CONFIRMED' 'FALSE POSITIVE'
#  'FALSE POSITIVE' 'CONFIRMED' 'CANDIDATE']
# Actual Labels: ['CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED', 'CANDIDATE', 'FALSE POSITIVE', 'CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CANDIDATE', 'CANDIDATE', 'CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED', 'CANDIDATE']
