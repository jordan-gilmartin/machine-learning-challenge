# %%
import pandas as pd

# %%
df = pd.read_csv("exoplanet_data.csv")
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
df.shape
# Out:
# (6991, 41)

# %%
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
df.shape
# Out:
# (6991, 41)

# %%
# Set features. This will also be used as your x values.
# selected_features = df[['names', 'of', 'selected', 'features', 'here']]
X = df.drop("koi_disposition", axis=1)
y = df["koi_disposition"]
print(X.shape, y.shape)
# Out:
# (6991, 40) (6991,)

# %%
feature_names = X.columns

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Scale your data
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.8598398169336384

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.9038901601830663

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.10652044182808494, 'koi_fpflag_co'),
#  (0.08737418001712767, 'koi_fpflag_nt'),
#  (0.06221288491335688, 'koi_fpflag_ss'),
#  (0.05852714991832765, 'koi_model_snr'),
#  (0.05066214995777821, 'koi_prad'),
#  (0.04341605348117173, 'koi_prad_err2'),
#  (0.03469143057149866, 'koi_fpflag_ec'),
#  (0.03364648381243898, 'koi_duration_err2'),
#  (0.030815373376770743, 'koi_prad_err1'),
#  (0.02994545918891724, 'koi_steff_err1'),
#  (0.029576551889401507, 'koi_steff_err2'),
#  (0.027343429781838596, 'koi_duration_err1'),
#  (0.02529477674764551, 'koi_time0bk_err2'),
#  (0.023829938052574474, 'koi_time0bk_err1'),
#  (0.023232810110540358, 'koi_period'),
#  (0.022426037916785796, 'koi_duration'),
#  (0.019450795825151225, 'koi_insol_err1'),
#  (0.019264732096719816, 'koi_depth'),
#  (0.01889054298677645, 'koi_impact'),
#  (0.01689402169186853, 'koi_period_err2'),
#  (0.016688172843822763, 'koi_teq'),
#  (0.01577033651124857, 'koi_period_err1'),
#  (0.01563730495430157, 'koi_insol'),
#  (0.015007149630270882, 'koi_insol_err2'),
#  (0.014491468701857843, 'koi_time0bk'),
#  (0.013753290508219876, 'koi_depth_err1'),
#  (0.013209206422086976, 'ra'),
#  (0.013174861964110697, 'koi_depth_err2'),
#  (0.012820383805294967, 'koi_srad_err1'),
#  (0.011915731200849941, 'dec'),
#  (0.01139787071538806, 'koi_impact_err1'),
#  (0.011330298838178774, 'koi_impact_err2'),
#  (0.011186397427186072, 'koi_slogg_err2'),
#  (0.010854848463077094, 'koi_kepmag'),
#  (0.009909594889160612, 'koi_steff'),
#  (0.009081156341676187, 'koi_slogg_err1'),
#  (0.009008276949805554, 'koi_srad'),
#  (0.00881109132780998, 'koi_srad_err2'),
#  (0.008660561225279887, 'koi_slogg'),
#  (0.003276753115598649, 'koi_tce_plnt_num')]

# %%
feature_names
# Out:
# Index(['koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co', 'koi_fpflag_ec',
#        'koi_period', 'koi_period_err1', 'koi_period_err2', 'koi_time0bk',
#        'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact', 'koi_impact_err1',
#        'koi_impact_err2', 'koi_duration', 'koi_duration_err1',
#        'koi_duration_err2', 'koi_depth', 'koi_depth_err1', 'koi_depth_err2',
#        'koi_prad', 'koi_prad_err1', 'koi_prad_err2', 'koi_teq', 'koi_insol',
#        'koi_insol_err1', 'koi_insol_err2', 'koi_model_snr', 'koi_tce_plnt_num',
#        'koi_steff', 'koi_steff_err1', 'koi_steff_err2', 'koi_slogg',
#        'koi_slogg_err1', 'koi_slogg_err2', 'koi_srad', 'koi_srad_err1',
#        'koi_srad_err2', 'ra', 'dec', 'koi_kepmag'],
#       dtype='object')
